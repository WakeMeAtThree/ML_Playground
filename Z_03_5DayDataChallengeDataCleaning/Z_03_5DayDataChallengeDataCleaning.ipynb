# %% [markdown]
# # [Data Cleaning Challenge Handling missing values](https://www.kaggle.com/rtatman/data-cleaning-challenge-handling-missing-values)
# # Day 1

# %%
import pandas as pd
import numpy as np

nfl_data = pd.read_csv("../../datasets/NFL Play by Play 2009-2017 (v4).csv")
sf_permits = pd.read_csv("../../datasets/Building_Permits.csv")

np.random.seed(0)
# Out:
# c:\users\alqu\miniconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# c:\users\alqu\miniconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Inspecting rows to spot missing values

# %%
nfl_data.sample(5)
# Out:
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 244485  2014-10-26  2014102607     18    3   1.0  00:39          1     939.0
# 115340  2011-11-20  2011112000     22    4   1.0  06:47          7     407.0
# 68357   2010-11-14  2010111401      8    2   NaN  00:23          1    1823.0
# 368377  2017-09-24  2017092405     24    4   1.0  08:48          9     528.0
# 384684  2017-11-05  2017110505     11    2   1.0  09:15         10    2355.0
#
#         PlayTimeDiff SideofField   ...      yacEPA  Home_WP_pre  Away_WP_pre  \
# 244485          12.0          TB   ...    1.240299     0.225647     0.774353
# 115340          44.0         OAK   ...         NaN     0.056036     0.943964
# 68357            0.0         CLE   ...         NaN     0.365307     0.634693
# 368377           8.0         CLE   ...    1.075660     0.935995     0.064005
# 384684           0.0         DEN   ...         NaN     0.928474     0.071526
#
# ...

# %% [markdown]
# # Does sf_permits dataset have missing values?
# Yes

# %%
sf_permits.sample(5)
# Out:
#        Permit Number  Permit Type  Permit Type Definition  \
# 78651   201503120624            8  otc alterations permit
# 177779  201707071220            8  otc alterations permit
# 64978        M529127            8  otc alterations permit
# 165958  201704073507            8  otc alterations permit
# 147902  201701237639            8  otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# 78651            03/12/2015  4273   029           2986                  NaN
# 177779           07/07/2017  0453  004A            950                  NaN
# 64978            10/21/2014  0478   011           1290                  NaN
# 165958           04/07/2017  6507  003A           1134                  NaN
# 147902           01/23/2017  0623   001           1755                  NaN
#
#        Street Name Street Suffix      ...        Existing Construction Type  \
# 78651         26th            St      ...                               5.0
# ...

# %% [markdown]
# # Finding nulls quickly
# Using isnull() and summing it is a more streamlined approach to find nulls.

# %%
missing_values_count = nfl_data.isnull().sum()
missing_values_count[0:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            61154
# time              224
# TimeUnder           0
# TimeSecs          224
# PlayTimeDiff      444
# SideofField       528
# dtype: int64

# %% [markdown]
# # Percentage of missing values
# nfl_data

# %%
total_cells = np.product(nfl_data.shape)
total_missing = missing_values_count.sum()

(total_missing/total_cells) * 100
# Out:
# 24.87214126835169

# %% [markdown]
# sf_permits

# %%
missing_values_count_sf = sf_permits.isnull().sum()
total_cells_sf = np.product(sf_permits.shape)
total_missing_sf = missing_values_count_sf.sum()

(total_missing_sf/total_cells_sf) * 100
# Out:
# 26.26002315058403

# %% [markdown]
# # Why is the data missing?
# - is the value missing because it wasn't recorded
#     - example:
#     - then impute
# - or because it doesn't exist?
#     - example: height of the oldest child of someone who doesn't have any children => doesn't make sense
#
# **Read the dataset documentation to find out if it's missing for a good reason or not**

# %%
missing_values_count[0:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            61154
# time              224
# TimeUnder           0
# TimeSecs          224
# PlayTimeDiff      444
# SideofField       528
# dtype: int64

# %%
sf_permits[['Street Number Suffix','Street Number','Zipcode']].isnull()
# Out:
#         Street Number Suffix  Street Number  Zipcode
# 0                       True          False    False
# 1                       True          False    False
# 2                       True          False    False
# 3                       True          False    False
# 4                       True          False    False
# 5                       True          False    False
# 6                       True          False    False
# 7                       True          False    False
# 8                       True          False    False
# 9                       True          False    False
# 10                      True          False    False
# 11                      True          False    False
# 12                      True          False    False
# 13                      True          False    False
# 14                      True          False    False
# 15                      True          False    False
# 16                      True          False    False
# ...

# %%
missing_values_count_sf
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %% [markdown]
# Find out if missing values for the following are missing for what reason:
# - `Street Number Suffix`
# - `Zipcode`
#
# From the dictionary description, we know that
#
# | Item | Description |
# | :--- | --- |
# | `Street Number Suffix` | Related to address |
# | `Zipcode`| Zipcode of building address |
#
# ____
#
# To be continued.
