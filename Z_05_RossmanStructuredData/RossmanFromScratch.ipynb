# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Diagram
#
# ![](map.jpg)

# %%
from fastai.structured import *
from fastai.column_data import *
np.set_printoptions(threshold=50, edgeitems=20)

PATH='data/rossmann/'

# %%
# Select csv table names
selection = [i for i in os.listdir(PATH) if i.endswith('.csv')]

# Read csv tables
tables = [pd.read_csv(f"{PATH}{i}", low_memory=False) for i in selection]

# Assign csv tables to their own vars
googletrend,sample_submission,state_names,store,store_states,test,train,weather=tables

# %%
from IPython.display import HTML

# %%
# Display all tables head
for i,t in enumerate(tables): 
    print("___________")
    print(selection[i])
    display(t.head())
# Out:
# ___________
# googletrend.csv
#              file                     week  trend
# 0  Rossmann_DE_SN  2012-12-02 - 2012-12-08     96
# 1  Rossmann_DE_SN  2012-12-09 - 2012-12-15     95
# 2  Rossmann_DE_SN  2012-12-16 - 2012-12-22     91
# 3  Rossmann_DE_SN  2012-12-23 - 2012-12-29     48
# 4  Rossmann_DE_SN  2012-12-30 - 2013-01-05     67
# ___________
# sample_submission.csv
#    Id  Sales
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
# ___________
# state_names.csv
#            StateName State
# 0  BadenWuerttemberg    BW
# 1             Bayern    BY
# 2             Berlin    BE
# 3        Brandenburg    BB
# 4             Bremen    HB
# ___________
# store.csv
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN
# ___________
# store_states.csv
#    Store State
# 0      1    HE
# 1      2    TH
# 2      3    NW
# 3      4    BE
# 4      5    SN
# ___________
# test.csv
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0
# ___________
# train.csv
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ___________
# weather.csv
#                  file        Date  Max_TemperatureC  Mean_TemperatureC  \
# 0  NordrheinWestfalen  2013-01-01                 8                  4
# 1  NordrheinWestfalen  2013-01-02                 7                  4
# 2  NordrheinWestfalen  2013-01-03                11                  8
# 3  NordrheinWestfalen  2013-01-04                 9                  9
# 4  NordrheinWestfalen  2013-01-05                 8                  8
#
#    Min_TemperatureC  Dew_PointC  MeanDew_PointC  Min_DewpointC  Max_Humidity  \
# 0                 2           7               5              1            94
# 1                 1           5               3              2            93
# 2                 6          10               8              4           100
# 3                 8           9               9              8           100
# 4                 7           8               7              6           100
#
#    Mean_Humidity       ...        Max_VisibilityKm  Mean_VisibilityKm  \
# 0             87       ...                    31.0               12.0
# 1             85       ...                    31.0               14.0
# 2             93       ...                    31.0                8.0
# 3             94       ...                    11.0                5.0
# 4             94       ...                    10.0                6.0
#
#    Min_VisibilitykM  Max_Wind_SpeedKm_h  Mean_Wind_SpeedKm_h  \
# 0               4.0                  39                   26
# 1              10.0                  24                   16
# 2               2.0                  26                   21
# 3               2.0                  23                   14
# 4               3.0                  16                   10
#
#    Max_Gust_SpeedKm_h  Precipitationmm  CloudCover  Events  WindDirDegrees
# 0                58.0             5.08         6.0    Rain             215
# 1                 NaN             0.00         6.0    Rain             225
# 2                 NaN             1.02         7.0    Rain             240
# 3                 NaN             0.25         7.0    Rain             263
# 4                 NaN             0.00         7.0    Rain             268
#
# [5 rows x 24 columns]

# %%
for i,t in enumerate(tables): 
    print("___________")
    print(selection[i])
    display((DataFrameSummary(t)).summary())
# Out:
# ___________
# googletrend.csv
# C:\Users\AlQu\Miniconda3\envs\fastai\lib\site-packages\pandas_summary\__init__.py:62: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   return pd.concat([self.df.describe(), self.columns_stats])[self.df.columns]
#                      file         week    trend
# count                 NaN          NaN     2072
# mean                  NaN          NaN  63.8142
# std                   NaN          NaN  12.6502
# min                   NaN          NaN        0
# 25%                   NaN          NaN       55
# 50%                   NaN          NaN       64
# 75%                   NaN          NaN       72
# max                   NaN          NaN      100
# counts               2072         2072     2072
# uniques                14          148       68
# missing                 0            0        0
# missing_perc           0%           0%       0%
# types         categorical  categorical  numeric
# ___________
# sample_submission.csv
#                    Id     Sales
# count           41088     41088
# mean          20544.5         0
# std           11861.2         0
# min                 1         0
# 25%           10272.8         0
# 50%           20544.5         0
# 75%           30816.2         0
# max             41088         0
# counts          41088     41088
# uniques         41088         1
# missing             0         0
# missing_perc       0%        0%
# types         numeric  constant
# ___________
# state_names.csv
#              StateName   State
# count               16      16
# unique              16      16
# top             Berlin      HH
# freq                 1       1
# counts              16      16
# uniques             16      16
# missing              0       0
# missing_perc        0%      0%
# types           unique  unique
# ___________
# store.csv
#                 Store    StoreType   Assortment CompetitionDistance  \
# count            1115          NaN          NaN                1112
# mean              558          NaN          NaN              5404.9
# std           322.017          NaN          NaN             7663.17
# min                 1          NaN          NaN                  20
# 25%             279.5          NaN          NaN               717.5
# 50%               558          NaN          NaN                2325
# 75%             836.5          NaN          NaN              6882.5
# max              1115          NaN          NaN               75860
# counts           1115         1115         1115                1112
# uniques          1115            4            3                 654
# missing             0            0            0                   3
# missing_perc       0%           0%           0%               0.27%
# types         numeric  categorical  categorical             numeric
#
#              CompetitionOpenSinceMonth CompetitionOpenSinceYear    Promo2  \
# count                              761                      761      1115
# mean                            7.2247                  2008.67  0.512108
# std                            3.21235                  6.19598  0.500078
# min                                  1                     1900         0
# 25%                                  4                     2006         0
# 50%                                  8                     2010         1
# 75%                                 10                     2013         1
# max                                 12                     2015         1
# counts                             761                      761      1115
# uniques                             12                       23         2
# missing                            354                      354         0
# missing_perc                    31.75%                   31.75%        0%
# types                          numeric                  numeric      bool
#
#              Promo2SinceWeek Promo2SinceYear PromoInterval
# count                    571             571           NaN
# mean                 23.5954         2011.76           NaN
# std                   14.142         1.67494           NaN
# min                        1            2009           NaN
# 25%                       13            2011           NaN
# 50%                       22            2012           NaN
# 75%                       37            2013           NaN
# max                       50            2015           NaN
# counts                   571             571           571
# uniques                   24               7             3
# missing                  544             544           544
# missing_perc          48.79%          48.79%        48.79%
# types                numeric         numeric   categorical
# ___________
# store_states.csv
#                 Store        State
# count            1115          NaN
# mean              558          NaN
# std           322.017          NaN
# min                 1          NaN
# 25%             279.5          NaN
# 50%               558          NaN
# 75%             836.5          NaN
# max              1115          NaN
# counts           1115         1115
# uniques          1115           12
# missing             0            0
# missing_perc       0%           0%
# types         numeric  categorical
# ___________
# test.csv
#                    Id    Store DayOfWeek         Date      Open     Promo  \
# count           41088    41088     41088          NaN     41077     41088
# mean          20544.5    555.9   3.97917          NaN  0.854322  0.395833
# std           11861.2  320.274   2.01548          NaN  0.352787  0.489035
# min                 1        1         1          NaN         0         0
# 25%           10272.8   279.75         2          NaN         1         0
# 50%           20544.5    553.5         4          NaN         1         0
# 75%           30816.2   832.25         6          NaN         1         1
# max             41088     1115         7          NaN         1         1
# counts          41088    41088     41088        41088     41077     41088
# uniques         41088      856         7           48         2         2
# missing             0        0         0            0        11         0
# missing_perc       0%       0%        0%           0%     0.03%        0%
# types         numeric  numeric   numeric  categorical      bool      bool
#
#              StateHoliday SchoolHoliday
# count                 NaN         41088
# mean                  NaN      0.443487
# std                   NaN      0.496802
# min                   NaN             0
# 25%                   NaN             0
# 50%                   NaN             0
# 75%                   NaN             1
# max                   NaN             1
# counts              41088         41088
# uniques                 2             2
# missing                 0             0
# missing_perc           0%            0%
# types                bool          bool
# ___________
# train.csv
#                     Store    DayOfWeek         Date        Sales    Customers  \
# count         1.01721e+06  1.01721e+06          NaN  1.01721e+06  1.01721e+06
# mean               558.43      3.99834          NaN      5773.82      633.146
# std               321.909      1.99739          NaN      3849.93      464.412
# min                     1            1          NaN            0            0
# 25%                   280            2          NaN         3727          405
# 50%                   558            4          NaN         5744          609
# 75%                   838            6          NaN         7856          837
# max                  1115            7          NaN        41551         7388
# counts            1017209      1017209      1017209      1017209      1017209
# uniques              1115            7          942        21734         4086
# missing                 0            0            0            0            0
# missing_perc           0%           0%           0%           0%           0%
# types             numeric      numeric  categorical      numeric      numeric
#
#                      Open        Promo StateHoliday SchoolHoliday
# count         1.01721e+06  1.01721e+06          NaN   1.01721e+06
# mean             0.830107     0.381515          NaN      0.178647
# std              0.375539     0.485759          NaN      0.383056
# min                     0            0          NaN             0
# 25%                     1            0          NaN             0
# 50%                     1            0          NaN             0
# 75%                     1            1          NaN             0
# max                     1            1          NaN             1
# counts            1017209      1017209      1017209       1017209
# uniques                 2            2            4             2
# missing                 0            0            0             0
# missing_perc           0%           0%           0%            0%
# types                bool         bool  categorical          bool
# ___________
# weather.csv
#                      file         Date Max_TemperatureC Mean_TemperatureC  \
# count                 NaN          NaN            15840             15840
# mean                  NaN          NaN          14.6441            10.389
# std                   NaN          NaN          8.64601           7.37926
# min                   NaN          NaN              -11               -13
# 25%                   NaN          NaN                8                 4
# 50%                   NaN          NaN               15                11
# 75%                   NaN          NaN               21                16
# max                   NaN          NaN               39                31
# counts              15840        15840            15840             15840
# uniques                16          990               51                45
# missing                 0            0                0                 0
# missing_perc           0%           0%               0%                0%
# types         categorical  categorical          numeric           numeric
#
#              Min_TemperatureC Dew_PointC MeanDew_PointC Min_DewpointC  \
# count                   15840      15840          15840         15840
# mean                  6.19899    8.58782        6.20581       3.62614
# std                   6.52639    6.24478        6.08677       6.12839
# min                       -15        -14            -15           -73
# 25%                         1          4              2            -1
# 50%                         7          9              7             4
# 75%                        11         13             11             8
# max                        24         25             20            19
# counts                  15840      15840          15840         15840
# uniques                    40         40             36            40
# missing                     0          0              0             0
# missing_perc               0%         0%             0%            0%
# types                 numeric    numeric        numeric       numeric
#
#              Max_Humidity Mean_Humidity      ...       Max_VisibilityKm  \
# count               15840         15840      ...                  15459
# mean              93.6596       74.2829      ...                24.0576
# std               7.67853       13.4866      ...                 8.9768
# min                    44            30      ...                      0
# 25%                 90.75            65      ...                     14
# 50%                    94            76      ...                     31
# 75%                   100            85      ...                     31
# max                   100           100      ...                     31
# counts              15840         15840      ...                  15459
# uniques                53            71      ...                     24
# missing                 0             0      ...                    381
# missing_perc           0%            0%      ...                  2.41%
# types             numeric       numeric      ...                numeric
#
#              Mean_VisibilityKm Min_VisibilitykM Max_Wind_SpeedKm_h  \
# count                    15459            15459              15840
# mean                   12.2398          7.02516            22.7666
# std                    5.06794           4.9806            8.98862
# min                          0                0                  3
# 25%                         10                3                 16
# 50%                         11                7                 21
# 75%                         14               10                 27
# max                         31               31                101
# counts                   15459            15459              15840
# uniques                     32               24                 44
# missing                    381              381                  0
# missing_perc             2.41%            2.41%                 0%
# types                  numeric          numeric            numeric
#
#              Mean_Wind_SpeedKm_h Max_Gust_SpeedKm_h Precipitationmm  \
# count                      15840               3604           15840
# mean                     11.9722            48.8643        0.831718
# std                      5.87284             13.027         2.51351
# min                            2                 21               0
# 25%                            8                 39               0
# 50%                           11                 48               0
# 75%                           14                 55            0.25
# max                           53                111           58.93
# counts                     15840               3604           15840
# uniques                       29                 47              41
# missing                        0              12236               0
# missing_perc                  0%             77.25%              0%
# types                    numeric            numeric         numeric
#
#              CloudCover       Events WindDirDegrees
# count             14667          NaN          15840
# mean            5.55131          NaN        175.897
# std             1.68771          NaN        101.589
# min                   0          NaN             -1
# 25%                   5          NaN             80
# 50%                   6          NaN            202
# 75%                   7          NaN            256
# max                   8          NaN            360
# counts            14667        11889          15840
# uniques               9           21            362
# missing            1173         3951              0
# missing_perc      7.41%       24.94%             0%
# types           numeric  categorical        numeric
#
# [13 rows x 24 columns]

# %% [markdown]
# # Data cleaning
# To do list for each table:
# - train/test
#     - booleanify stateholiday/schoolholiday
# - Weather
#     - join weather with state_names
# - Googletrend
#     - separate week into two dates, get first date
#     - separate `Rossman_DE_%` into separate states and all of germany
#     - fix abbreviations (make sure they're common with other relational table)
#
# **EXPAND DATE PARTS for train,test, weather, googletrend**
#
# - Isolate ROSSMAN_DE to `trend_de`
# - join store with store_states on STORE
# - join train/test with store on STORE to JOINED/JOINED_TEST
# - join JOINED/JOINED_TEST with googletrend on State-Year-Week
# - join JOINED/JOINED_TEST with trend_de on Year-Week
# - join JOINED/JOINED_TEST with weather on State-Date
#
# - Remove duplicate columns (ending with _y)
# - FOR joined + joined_test, fill missing items in CompOpenSinceYear,Month, Promo2SinceYear/Week
#
# # Extract Features
#
# - FOR joined + joined_test, create datetime objects for `CompetitionOpenSince` and `CompetitionDaysOpen`
# - FOR joined + joined_test, remove outliers + error data (make sure subtraction results are not negative)
# - FOR joined + joined_test, added `CompetitionMonthsOpen` and constrain it to 24 months.
# - FOR joined + joined_test, repeat for Promo dates `Promo2Since` and `Promo2Days`
# - FOR joined + joined_test, create `Promo2Weeks` and constrain  to 25 weeks
# - Back up `.to_feather()`
#
# # Durations
#
# Incomplete

# %%
#booleanify the bools
train.StateHoliday = train.StateHoliday != '0'
test.StateHoliday = test.StateHoliday != '0'
train.SchoolHoliday = train.SchoolHoliday.astype(bool)
test.SchoolHoliday = test.SchoolHoliday.astype(bool)

# %%
#Join weather with state names
weather = weather.merge(state_names, how="left",left_on=["file"],right_on=["StateName"],suffixes=['',"_y"])

# %%
# Googletrend cleaning
googletrend["State"] = googletrend.file.str.split("_",expand=True)[2]
googletrend.loc[googletrend.State=="NI","State"]="HB,NI"
googletrend["Date"] = googletrend.week.str.split(" - ",expand=True)[0]

# %%
columns = ["Date", "State", "trend"]
googletrend = googletrend[columns]

# %% [markdown]
# So apparently, Rossman doesn't have a store in SL.

# %%
add_datepart(weather,"Date",drop=False)
add_datepart(googletrend,"Date",drop=False)
add_datepart(train,"Date",drop=False)
add_datepart(test,"Date",drop=False)
# Out:
# C:\Users\AlQu\Miniconda3\envs\fastai\lib\site-packages\fastai\structured.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[fldname] = fld = pd.to_datetime(fld, infer_datetime_format=True)
# C:\Users\AlQu\Miniconda3\envs\fastai\lib\site-packages\fastai\structured.py:114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   for n in attr: df[targ_pre + n] = getattr(fld.dt, n.lower())

# %%
trend_de = googletrend[pd.isnull(googletrend["State"])]

# %%
#join stores
store = store.merge(store_states,how='left',left_on='Store',right_on='Store',suffixes=["","_y"])

# %%
joined = train.merge(store,how='left',left_on='Store',right_on='Store',suffixes=["","_y"])
joined_test = test.merge(store,how='left',left_on='Store',right_on='Store',suffixes=["","_y"])

# %%
joined = joined.merge(googletrend,'left',['State', 'Year', 'Week'],suffixes=["","_y"])
joined_test = joined_test.merge(googletrend,'left',['State', 'Year', 'Week'],suffixes=["","_y"])

# %%
joined = joined.merge(trend_de,'left',[ 'Year', 'Week'],suffixes=["","_DE"])
joined_test = joined_test.merge(trend_de,'left',[ 'Year', 'Week'],suffixes=["","_DE"])

# %%
joined = joined.merge(weather,'left',['State', 'Date'],suffixes=["","_y"])
joined_test = joined_test.merge(weather,'left',['State', 'Date'],suffixes=["","_y"])

# %%
#remove duplicate columns
columns = [i for i in joined.columns if not(i.endswith("_y"))]
joined = joined[columns]

# %%
columns = [i for i in joined_test.columns if not(i.endswith("_y"))]
joined_test = joined_test[columns]

# %%
print(len(joined),len(joined_test),end='\n')
print(len(joined.columns),len(joined_test.columns))
print(set(joined.columns)-set(joined_test.columns))
# Out:
# 1017209 41088
# 71 70
# {'Sales', 'Customers'}

# %%
# fill missing items in dates
for df in (joined,joined_test):
    df['CompetitionOpenSinceYear']=df['CompetitionOpenSinceYear'].fillna(1900)
    df['CompetitionOpenSinceMonth']=df['CompetitionOpenSinceMonth'].fillna(1)
    df['Promo2SinceYear'] = df['Promo2SinceYear'] .fillna(1900)
    df['Promo2SinceWeek'] = df['Promo2SinceWeek'].fillna(1)

# %% [markdown]
# # Extract Features

# %%
for df in (joined,joined_test):
    param = dict(year=df['CompetitionOpenSinceYear'],month=df['CompetitionOpenSinceMonth'],day=15)
    df['CompetitionOpenSince'] = pd.to_datetime(param)

# %%
for df in (joined,joined_test):
    df['CompetitionDaysOpen'] = df.Date.subtract(df['CompetitionOpenSince']).dt.days

# %%
for df in (joined, joined_test):
    df.loc[df.CompetitionDaysOpen<0,'CompetitionDaysOpen'] = 0
    df.loc[df.CompetitionOpenSinceYear<1990,'CompetitionDaysOpen'] = 0

# %%
def constrain(val, R1, R2):
    if(val > R2): return R2
    if(val < R1): return R1
    return val

# %%
for df in (joined, joined_test):
    df['CompetitionMonthsOpen']=(df['CompetitionDaysOpen']//30).apply(lambda x: constrain(x,0,24))

# %%
joined.Promo2SinceWeek = joined.Promo2SinceWeek.astype(int)
joined.Promo2SinceYear = joined.Promo2SinceYear.astype(int)

# %%
joined_test.Promo2SinceWeek = joined_test.Promo2SinceWeek.astype(int)
joined_test.Promo2SinceYear = joined_test.Promo2SinceYear.astype(int)

# %%
for df in (joined,joined_test):
    df["Promo2Since"] = pd.to_datetime(df.apply(lambda x: Week(
        x.Promo2SinceYear, x.Promo2SinceWeek).monday(), axis=1).astype(pd.datetime))
    df["Promo2Days"] = df.Date.subtract(df["Promo2Since"]).dt.days

# %%
for df in (joined,joined_test):
    df.loc[df['Promo2Days']<0,"Promo2Days"] = 0
    df['Promo2Weeks']=(df['Promo2Days']//7).apply(partial(constrain,R1=0,R2=25))

# %%
joined.to_feather(f"{PATH}joinedS1")
joined_test.to_feather(f"{PATH}joined_testS1")

# %%
#joined.sort_values(['Store','Date'],ascending=[True,True])[['Store','Date','SchoolHoliday']]

# %%
def get_elapsed(fld, pre, df):
    """This function expects sorted dataframe
    before running, on Store-Date values"""
    day1 = np.timedelta64(1, 'D')
    last_seen_date = np.datetime64()
    last_store = 0
    res = []
    
    #for Store, isitaholiday?, Date
    for s,v,d in zip(df.Store.values,df[fld].values, df.Date.values):
        if s != last_store:
            last_seen_date = np.datetime64()
            last_store = s
        if v: last_seen_date = d
        res.append(((d-last_seen_date).astype('timedelta64[D]') / day1))
    df[pre+fld] = res

# %%
columns = ['StateHoliday', 'SchoolHoliday','Promo']
#Optional, recreate closeddays

# %%
def func(df, columnName):
    df = df.sort_values(['Store','Date'])
    get_elapsed(columnName,'After',df)
    df = df.sort_values(['Store','Date'],ascending=[True, False])
    get_elapsed(columnName,'Before',df)
    return df

# %%
#Later on, we can perhaps do it `for i in columns`
joined = func(joined, 'StateHoliday')
joined_test = func(joined_test,'StateHoliday')

# %%
joined = func(joined, 'SchoolHoliday')
joined_test = func(joined_test,'SchoolHoliday')

# %%
joined = func(joined, 'Promo')
joined_test = func(joined_test,'Promo')

# %%
joined.set_index('Date',inplace=True)
joined_test.set_index('Date',inplace=True)

# %%
for i in columns:
    for j in ['After','Before']:
        joined[j+i]=joined[j+i].fillna(0).astype(int)

# %%
for i in columns:
    for j in ['After','Before']:
        joined_test[j+i]=joined_test[j+i].fillna(0).astype(int)

# %%
def rollingQuants(df):
    fwd = df[['Store']+columns].sort_index().groupby('Store').rolling(7,min_periods=1).sum()
    bwd = df[['Store']+columns].sort_index().groupby('Store').rolling(7,min_periods=1).sum()
    return fwd,bwd

# %%
fwd,bwd=rollingQuants(joined)
fwd2,bwd2=rollingQuants(joined_test)

# %%
def cleanGroup(df):
    df.drop('Store',1,inplace=True)
    df.reset_index(inplace=True)

# %%
cleanGroup(fwd)
cleanGroup(bwd)
cleanGroup(fwd2)
cleanGroup(bwd2)

# %%
joined = joined.merge(fwd,'left',['Store','Date'],suffixes=['','_fw'])
joined = joined.merge(bwd,'left',['Store','Date'],suffixes=['','_bw'])
joined_test = joined_test.merge(fwd2,'left',['Store','Date'],suffixes=['','_fw'])
joined_test = joined_test.merge(bwd2,'left',['Store','Date'],suffixes=['','_bw'])

# %%
cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day','CompetitionMonthsOpen',
    'Promo2Weeks', 'StoreType', 'Assortment', 'PromoInterval', 'CompetitionOpenSinceYear', 'Promo2SinceYear',
    'State', 'Week', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_fw', 'StateHoliday_bw',
    'SchoolHoliday_fw', 'SchoolHoliday_bw']

contin_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday', 'BeforeStateHoliday', 'Promo', 'SchoolHoliday']

# %%
depVar = 'Sales'
joined = joined[cat_vars+contin_vars+[depVar,'Date']].copy()
joined_test[depVar] = 0
joined_test = joined_test[cat_vars+contin_vars+[depVar,'Date','Id']].copy()

# %%
joined["Date"] = pd.to_datetime(joined.Date)
joined_test["Date"] = pd.to_datetime(joined_test.Date)

# %%
for i in cat_vars: 
    joined[i] = joined[i].astype('category').cat.as_ordered()

apply_cats(joined_test,joined)

for i in (contin_vars+[depVar]): 
    joined[i] = joined[i].astype('float32')
    joined_test[i] = joined_test[i].astype('float32')



joined.set_index('Date')
joined_test.set_index('Date')
# Out:
#            Store DayOfWeek  Year Month Day CompetitionMonthsOpen Promo2Weeks  \
# Date
# 2015-09-17     1         4  2015     9  17                    24          25
# 2015-09-16     1         3  2015     9  16                    24          25
# 2015-09-15     1         2  2015     9  15                    24          25
# 2015-09-14     1         1  2015     9  14                    24          25
# 2015-09-13     1         7  2015     9  13                    24          25
# 2015-09-12     1         6  2015     9  12                    24          25
# 2015-09-11     1         5  2015     9  11                    24          25
# 2015-09-10     1         4  2015     9  10                    24          25
# 2015-09-09     1         3  2015     9   9                    24          25
# 2015-09-08     1         2  2015     9   8                    24          25
# 2015-09-07     1         1  2015     9   7                    24          25
# 2015-09-06     1         7  2015     9   6                    24          25
# 2015-09-05     1         6  2015     9   5                    24          25
# 2015-08-22   0.0           1.0   0.0  23112
# 2015-08-21   1.0           1.0   0.0  23968
# 2015-08-20   1.0           1.0   0.0  24824
# 2015-08-19   1.0           1.0   0.0  25680
# 2015-08-18   1.0           1.0   0.0  26536
# 2015-08-17   1.0           1.0   0.0  27392
# 2015-08-16   0.0           1.0   0.0  28248
# 2015-08-15   0.0           1.0   0.0  29104
# 2015-08-14   0.0           1.0   0.0  29960
# 2015-08-13   0.0           1.0   0.0  30816
# 2015-08-12   0.0           1.0   0.0  31672
# 2015-08-11   0.0           1.0   0.0  32528
# 2015-08-10   0.0           1.0   0.0  33384
# 2015-08-09   0.0           1.0   0.0  34240
# 2015-08-08   0.0           1.0   0.0  35096
# 2015-08-07   1.0           1.0   0.0  35952
# 2015-08-06   1.0           1.0   0.0  36808
# 2015-08-05   1.0           1.0   0.0  37664
# 2015-08-04   1.0           1.0   0.0  38520
# 2015-08-03   1.0           1.0   0.0  39376
# 2015-08-02   0.0           1.0   0.0  40232
# 2015-08-01   0.0           1.0   0.0  41088
#
# [41088 rows x 39 columns]

# %%
proc_df(joined,'Sales',do_scale=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-5ebedcc69c41> in <module>()
# ----> 1 proc_df(joined,'Sales',do_scale=True)
#
# ~\Miniconda3\envs\fastai\lib\site-packages\fastai\structured.py in proc_df(df, y_fld, skip_flds, ignore_flds, do_scale, na_dict, preproc_fn, max_n_cat, subset, mapper)
#     436     for n,c in df.items(): na_dict = fix_missing(df, c, n, na_dict)
#     437     if do_scale: mapper = scale_vars(df, mapper)
# --> 438     for n,c in df.items(): numericalize(df, c, n, max_n_cat)
#     439     df = pd.get_dummies(df, dummy_na=True)
#     440     df = pd.concat([ignored_flds, df], axis=1)
#
# ~\Miniconda3\envs\fastai\lib\site-packages\fastai\structured.py in numericalize(df, col, name, max_n_cat)
#     317     """
#     318     if not is_numeric_dtype(col) and ( max_n_cat is None or col.nunique()>max_n_cat):
# --> 319         df[name] = col.cat.codes+1
#     320
#     321 def scale_vars(df, mapper):
#
# ~\Miniconda3\envs\fastai\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4366         if (name in self._internal_names_set or name in self._metadata or
#    4367                 name in self._accessors):
# -> 4368             return object.__getattribute__(self, name)
#    4369         else:
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Miniconda3\envs\fastai\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     130             # we're accessing the attribute of the class, i.e., Dataset.geo
#     131             return self._accessor
# --> 132         accessor_obj = self._accessor(obj)
#     133         # Replace the property with the accessor object. Inspired by:
#     134         # http://www.pydanny.com/cached-property.html
#
# ~\Miniconda3\envs\fastai\lib\site-packages\pandas\core\arrays\categorical.py in __init__(self, data)
#    2375
#    2376     def __init__(self, data):
# -> 2377         self._validate(data)
#    2378         self.categorical = data.values
#    2379         self.index = data.index
#
# ~\Miniconda3\envs\fastai\lib\site-packages\pandas\core\arrays\categorical.py in _validate(data)
#    2384     def _validate(data):
#    2385         if not is_categorical_dtype(data.dtype):
# -> 2386             raise AttributeError("Can only use .cat accessor with a "
#    2387                                  "'category' dtype")
#    2388
#
# AttributeError: Can only use .cat accessor with a 'category' dtype
